# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.style as style
import os
os.chdir('../')
style.use('seaborn')
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import easydict
from test_dd import main_test
total = []

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 1, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1.0,
    'client_decay':0,
    'local_decay':0,
    'alpha': 0.05,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)
# Out:
# INFO:root:{'model': 'ConvNet', 'dataset': 'cifar10', 'gpu': 0, 'iid': 0, 'epochs': 500, 'optimizer': 'sgd', 'seed': 0, 'norm': 'none', 'num_users': 50, 'frac': 0.2, 'local_ep': 1, 'local_bs': 32, 'lr': 0.01, 'momentum': 1, 'kernel_num': 9, 'kernel_sizes': 'only_momentum', 'num_channnels': '1', 'num_filters': 32, 'max_pool': 'True', 'num_classes': 10, 'unequal': 0, 'stopping_rounds': 0, 'verbose': 0, 'hold_normalize': 0, 'save_path': '../save/checkpoint/test', 'exp_folder': 'test', 'resume': None, 'server_opt': 'sgd', 'server_lr': 1.0, 'client_decay': 0, 'local_decay': 0, 'alpha': 0.05, 'server_epoch': 0, 'cosine_norm': 0, 'only_fc': 0, 'loss': 'vic', 'dc_lr': 0.0, 'tsne_pred': 0}
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:root:ConvNet(
#   (net_act): ReLU(inplace=True)
#   (net_pooling): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (features): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (classifier): Linear(in_features=2048, out_features=10, bias=True)
# )
# INFO:root:None
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 32, 32]           3,584
#               ReLU-2          [-1, 128, 32, 32]               0
#               ReLU-3          [-1, 128, 32, 32]               0
#          AvgPool2d-4          [-1, 128, 16, 16]               0
#          AvgPool2d-5          [-1, 128, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]         147,584
#               ReLU-7          [-1, 128, 16, 16]               0
#               ReLU-8          [-1, 128, 16, 16]               0
#          AvgPool2d-9            [-1, 128, 8, 8]               0
#         AvgPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 128, 8, 8]         147,584
#              ReLU-12            [-1, 128, 8, 8]               0
#              ReLU-13            [-1, 128, 8, 8]               0
#         AvgPool2d-14            [-1, 128, 4, 4]               0
#         AvgPool2d-15            [-1, 128, 4, 4]               0
#            Linear-16                   [-1, 10]          20,490
# ================================================================
# Total params: 319,242
# Trainable params: 319,242
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.59
# Params size (MB): 1.22
# Estimated Total Size (MB): 5.82
# ----------------------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# [209, 1756, 422, 2575, 1018, 602, 2274, 447, 744, 1112, 123, 87, 1433, 1416, 40, 1119, 796, 794, 327, 470, 231, 813, 1320, 542, 690, 2195, 2934, 106, 1012, 15, 278, 1798, 303, 590, 2029, 201, 1053, 862, 231, 116, 4600, 19, 286, 1736, 2430, 431, 3195, 1780, 173, 267]
# [470, 2934, 201, 231, 2575, 744, 15, 123, 1119, 4600]
#   0%|          | 0/500 [00:02<?, ?it/s]
# Evaluate_00: epoch = 0300  train loss = 0.000101 train acc = 1.0000, test acc = 0.1236
# Evaluate 1 random ConvNet, mean = 0.1236 std = 0.0000
# -------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4fbc0fcd86e0> in <module>
#      39     'tsne_pred':0 })
#      40 #그다음 nce and mae
# ---> 41 temp = main_test(args)
#      42 total.append(temp)
#
# ~/Projects/Federated-Learning/src/test_dd.py in main_test(args)
#     297             local_model = LocalUpdate(args=args, logger=logger, train_loader=client_loader_dict[idx], device=device, syn_client = syn_client[idx])
#     298             w, loss, batch_loss, conv_grad, fc_grad, total_gard_norm, syn_train,output_client,indices_class = local_model.update_weights(
# --> 299                 model=copy.deepcopy(global_model), global_round=epoch, idx_user=idx, syn_dataset = syn_round_dataset, images_all=images_all,train_dataset=train_dataset,test_dataset=test_dataset)
#     300
#     301             #with torch.no_grad():
#
# ~/Projects/Federated-Learning/src/update_upgrade_dc.py in update_weights(self, model, global_round, idx_user, syn_dataset, images_all, train_dataset, test_dataset)
#     388                     lab = torch.ones((ipc,), device=self.device, dtype=torch.long) * c
#     389                     output_syn = net(img_syn)
# --> 390                     loss_syn = criterion(output_syn, label_one_hot)
#     391                     gw_syn = torch.autograd.grad(loss_syn, net_parameters, create_graph=True)
#     392
#
# ~/miniconda/envs/fedml/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda/envs/fedml/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1119     def forward(self, input: Tensor, target: Tensor) -> Tensor:
#    1120         return F.cross_entropy(input, target, weight=self.weight,
# -> 1121                                ignore_index=self.ignore_index, reduction=self.reduction)
#    1122
#    1123
#
# ~/miniconda/envs/fedml/lib/python3.7/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2822     if size_average is not None or reduce is not None:
#    2823         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2824     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    2825
#    2826
#
# ValueError: Expected input batch_size (1) to match target batch_size (32).

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 1, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1,
    'client_decay':0,
    'local_decay':0,
    'alpha': 0.1,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 1, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1,
    'client_decay':0,
    'local_decay':0,
    'alpha': 1,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 10, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1,
    'client_decay':0,
    'local_decay':0,
    'alpha': 0.05,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 10, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1,
    'client_decay':0,
    'local_decay':0,
    'alpha': 0.1,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)

# %%
args = easydict.EasyDict({
    "model": 'ConvNet',
    'dataset': 'cifar10',
    'gpu': 0,
    'iid': 0,
    'epochs': 500,
    'optimizer': 'sgd',
    'seed': 0,
    'norm': 'none',
    'num_users': 50,
    'frac': 0.2,
    'local_ep': 10, 
    'local_bs': 32,
    'lr': 0.01,
    'momentum': 1,
    'kernel_num': 9,
    'kernel_sizes': 'only_momentum',
    'num_channnels': '1',
    'num_filters': 32,
    'max_pool': 'True',
    'num_classes': 10,
    'unequal': 0,
    'stopping_rounds': 0,
    'verbose': 0,
    'hold_normalize': 0,
    'save_path': '../save/checkpoint',
    'exp_folder': 'test',
    'resume': None,
    'server_opt': 'sgd',
    'server_lr': 1,
    'client_decay':0,
    'local_decay':0,
    'alpha': 1,
    'server_epoch':0,
    'cosine_norm':0, 
    'only_fc' :0 ,
    'loss':'vic',
    'dc_lr':0.0,
    'tsne_pred':0 })
#그다음 nce and mae
temp = main_test(args)
total.append(temp)
